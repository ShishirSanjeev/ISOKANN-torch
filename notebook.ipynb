# %%
import numpy as np
import pandas as pd
from data_loader import load_trajectories

# %%
file_list = [f"data/traj{i}.npy" for i in range(5)]
data = load_trajectories(file_list)

# %%
df = pd.DataFrame(data[:, :, :].reshape(-1, data.shape[2]))
df
# Out:
#              0
# 0    -1.206752
# 1    -1.488377
# 2    -1.393082
# 3    -1.148594
# 4    -1.309716
# ...        ...
# 4995  1.189607
# 4996  0.920350
# 4997  0.890059
# 4998  0.701461
# 4999  0.624387
#
# [5000 rows x 1 columns]

# %%
data.shape
# Out:
# (5, 1000, 1)

# %%
data[:, :-1, :].reshape(-1, data.shape[2])
# Out:
# array([[-1.20675202],
#        [-1.48837711],
#        [-1.39308225],
#        ...,
#        [ 0.92034963],
#        [ 0.8900589 ],
#        [ 0.70146091]], shape=(4995, 1))
